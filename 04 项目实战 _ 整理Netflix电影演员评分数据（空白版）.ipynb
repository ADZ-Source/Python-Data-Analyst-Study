# %% [markdown]
# # 项目：整理Netflix电影演员评分数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，整理不同流派影视作品，比如喜剧片、动作片、科幻片中，各演员出演作品的平均IMDB评分，从而挖掘出各个流派中的高评分作品演员。
#
# 本实战项目的目的在于练习整理数据，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了截止至2022年7月美国地区可观看的所有Netflix电视剧及电影数据。数据集包含两个数据表：`titles.csv`和`credits.csv`。
#
# `titles.csv`包含电影及电视剧相关信息，包括影视作品ID、标题、类型、描述、流派、IMDB（一个国外的在线评分网站）评分，等等。`credits.csv`包含超过7万名出现在Netflix影视作品的导演及演员信息，包括名字、影视作品ID、人物名、演职员类型（导演/演员）等。

# %% [markdown]
# `titles.csv`每列的含义如下：
# - id：影视作品ID。
# - title：影视作品标题。
# - show_type：作品类型，电视节目或电影。
# - description：简短描述。
# - release_year：发布年份。
# - age_certification：适龄认证。
# - runtime：每集电视剧或电影的长度。
# - genres：流派类型列表。
# - production_countries：出品国家列表。
# - seasons：如果是电视剧，则是季数。
# - imdb_id：IMDB的ID。
# - imdb_score：IMDB的评分。
# - imdb_votes：IMDB的投票数。
# - tmdb_popularity：TMDB的流行度。
# - tmdb_score：TMDB的评分。
#
# `credits.csv`每列的含义如下：
# - person_ID：演职员ID。
# - id：参与的影视作品ID。
# - name：姓名。
# - character_name：角色姓名。
# - role：演职员类型，演员或导演。

# %% [markdown]
# ## 读取数据

# %%
import pandas as pd

# %%
original_credits = pd.read_csv("credits.csv")

# %%
original_titles = pd.read_csv("titles.csv")

# %%
original_credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
original_credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %% [markdown]
# ## 评估于清理数据

# %% [markdown]
# 本环节是对刚刚建立的两个DataFrame `original_credits` , m`original_titles` 进行清理于评估。
#
# 主要由两个方向进行评估：结构和内容。
#
# 结构性为：“每个变量为一列，每个观察值为一行，每种类型的观察单位为一个表格”这三个标准；
# 数据的内容性问题包括存在丢失数据、重复数据、无效数据

# %% [markdown]
# 为了不修改到原数据，建立两个copy()DateFrame， `cleaned_credits` `cleaned_titles` ，来保存清理后的的数据

# %%
cleaned_credits = original_credits.copy()

# %%
cleaned_titles = original_titles.copy()

# %% [markdown]
# ### 数据整齐度

# %%
cleaned_titles.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
# 5   ts22164         Monty Python's Flying Circus   SHOW
# 6   tm70993                        Life of Brian  MOVIE
# 7   tm14873                          Dirty Harry  MOVIE
# 8  tm119281                     Bonnie and Clyde  MOVIE
# 9   tm98978                      The Blue Lagoon  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# ...

# %% [markdown]
# 从最初10行评估后发现， `cleaned_titles` 中的 `genres` 和 `production_countries` 包含超过一个值。需要被m分开

# %% [markdown]
# 先提取 `cleaned_titles` 中 `genres` 的一个值进行观察

# %%
cleaned_titles["genres"][1]
# Out:
# "['drama', 'crime']"

# %% [markdown]
# 修改genres为字符串. 调用函数方法 用 `eval` 方法来改变列表

# %%
cleaned_titles['genres'] = cleaned_titles['genres'].apply(lambda s: eval(s))
cleaned_titles["genres"][1]
# Out:
# ['drama', 'crime']

# %% [markdown]
# 用 `explode` 方法吧 genres分开

# %%
cleaned_titles = cleaned_titles.explode("genres")
cleaned_titles.head(5)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 2  Intent on seeing the Cahulawassee River before...          1972
#
#   age_certification  runtime         genres production_countries  seasons  \
# 0             TV-MA       51  documentation               ['US']      1.0
# ...

# %% [markdown]
# 接下来观察 `production_countries`

# %%
cleaned_titles["production_countries"][10]
# Out:
# 10    ['GB', 'US']
# 10    ['GB', 'US']
# 10    ['GB', 'US']
# Name: production_countries, dtype: object

# %% [markdown]
# 用同样的 `eval`方法来转变

# %%
cleaned_titles['production_countries'] = cleaned_titles['production_countries'].apply(lambda s: eval(s))
cleaned_titles["production_countries"][1]
# Out:
# 1    [US]
# 1    [US]
# Name: production_countries, dtype: object

# %% [markdown]
# 用同样的 `explode` 来分开

# %%
cleaned_titles = cleaned_titles.explode("production_countries")
cleaned_titles.head(5)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 2  tm154986                          Deliverance  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 2  Intent on seeing the Cahulawassee River before...          1972
#
#   age_certification  runtime         genres production_countries  seasons  \
# 0             TV-MA       51  documentation                   US      1.0
# ...

# %% [markdown]
# 开始处理 `cleaned_credits` 中的数据
# 先调出查看一下

# %%
cleaned_credits.head(10)
# Out:
#    person_id       id             name                      character   role
# 0       3748  tm84618   Robert De Niro                  Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster                  Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                            Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel        Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                          Betsy  ACTOR
# 5      32267  tm84618      Peter Boyle                         Wizard  ACTOR
# 6     519612  tm84618   Leonard Harris      Senator Charles Palantine  ACTOR
# 7      29068  tm84618   Diahnne Abbott                Concession Girl  ACTOR
# 8     519613  tm84618      Gino Ardito             Policeman at Rally  ACTOR
# 9       3308  tm84618  Martin Scorsese  Passenger Watching Silhouette  ACTOR

# %% [markdown]
# `cleaned_credits` 结构没有问题

# %% [markdown]
# ### 数据干净度

# %% [markdown]
# 通过 `info` 来观察数据是否干净

# %%
cleaned_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17818 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    17818 non-null  object
#  1   title                 17817 non-null  object
#  2   type                  17818 non-null  object
#  3   description           17790 non-null  object
#  4   release_year          17818 non-null  int64
#  5   age_certification     10889 non-null  object
#  6   runtime               17818 non-null  int64
#  7   genres                17755 non-null  object
#  8   production_countries  17439 non-null  object
#  9   seasons               6224 non-null   float64
#  10  imdb_id               17116 non-null  object
#  11  imdb_score            16976 non-null  float64
#  12  imdb_votes            16945 non-null  float64
#  13  tmdb_popularity       17663 non-null  float64
#  14  tmdb_score            17241 non-null  float64
# ...

# %% [markdown]
# `title` , `description`, `age_certification`, `genres`, `production_countries`, `seasons`, `imdb_id`,
# `imdb_score`, `imdb_votes`, `tmdb_popularity`, `tmdb_score` 都有NaN值，需要查看

# %% [markdown]
# 同时 `release_year` 应该为时间，而不是数字

# %%
cleaned_titles["release_year"] = pd.to_datetime(cleaned_titles["release_year"],format="%Y")
cleaned_titles["release_year"]
# Out:
# 0      1945-01-01
# 1      1976-01-01
# 1      1976-01-01
# 2      1972-01-01
# 2      1972-01-01
#           ...
# 5847   2021-01-01
# 5848   2021-01-01
# 5849   2021-01-01
# 5849   2021-01-01
# 5849   2021-01-01
# Name: release_year, Length: 17818, dtype: datetime64[ns]

# %%
cleaned_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB

# %% [markdown]
# `character` 有NaN值。需要查看

# %% [markdown]
# #### 处理丢失数据

# %% [markdown]
# `title` , `description`, `age_certification`, `genres`, `production_countries`, `seasons`, `imdb_id`,
# `imdb_score`, `imdb_votes`, `tmdb_popularity`, `tmdb_score` 数据都有都是
# 由于目的是查看高分作品，所有只有 `imdb_score`和`genres`是对高分作品有影响的数据。需要查看

# %% [markdown]
# 查看imdb_score中的NaN值

# %%
cleaned_titles.query("imdb_score.isnull()")
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 75     tm132164                       Bill Hicks: Sane Man  MOVIE
# 145    ts251477                            My First Errand   SHOW
# 145    ts251477                            My First Errand   SHOW
# 145    ts251477                            My First Errand   SHOW
# ...         ...                                        ...    ...
# 5810  tm1225897                                 Social Man  MOVIE
# 5833   ts307884                                 HQ Barbers   SHOW
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description release_year  \
# 0     This collection includes 12 World War II-era p...   1945-01-01
# ...

# %% [markdown]
# `imdb_score` 缺失核心数据。~可以删除~

# %%
cleaned_titles = cleaned_titles.dropna(subset=["imdb_score"])
cleaned_titles["imdb_score"].isnull().sum()
# Out:
# 0

# %% [markdown]
# 提出 `genres` 中的数据观察

# %%
cleaned_titles.query("genres.isnull()")
# Out:
#              id                                              title   type  \
# 1813    ts77824  My Next Guest Needs No Introduction With David...   SHOW
# 1939   ts215037                              Minecraft: Story Mode   SHOW
# 2386    ts74805                   A Little Help with Carol Burnett   SHOW
# 2658   ts265844                                           #ABtalks   SHOW
# 4274  tm1172010                                  The Lockdown Plan  MOVIE
# 4648  tm1113921                                           In Vitro  MOVIE
#
#                                             description release_year  \
# 1813  TV legend David Letterman teams up with fascin...   2018-01-01
# 1939  MInecraft: Story Mode is an interactive, anima...   2018-01-01
# 2386  In this unscripted series starring comedy lege...   2018-01-01
# 2658  #ABtalks is a YouTube interview show hosted by...   2018-01-01
# 4274                                                NaN   2020-01-01
# ...

# %% [markdown]
# 观察后的发现，关键值丢失。因为丢失所以对分析高分电影没有帮助。~可删除~ `genres`中的NaN值

# %%
cleaned_titles = cleaned_titles.dropna(subset=["genres"])
cleaned_titles["genres"].isnull().sum()
# Out:
# 0

# %% [markdown]
# 评估 `cleaned_credits` 中的空值。

# %%
cleaned_credits.query("character.isnull()")
# Out:
#        person_id         id              name character      role
# 36          3308    tm84618   Martin Scorsese       NaN  DIRECTOR
# 59         17727   tm154986      John Boorman       NaN  DIRECTOR
# 106        11475   tm127384       Terry Jones       NaN  DIRECTOR
# 107        11473   tm127384     Terry Gilliam       NaN  DIRECTOR
# 162         1063   tm120801    Robert Aldrich       NaN  DIRECTOR
# ...          ...        ...               ...       ...       ...
# 77776    2363022  tm1097142  Mohamed El-Arkan       NaN     ACTOR
# 77777    1827884  tm1097142     Mohamed Bakir       NaN  DIRECTOR
# 77783     678884  tm1014599      Segun Arinze       NaN     ACTOR
# 77789    1962840  tm1014599     Seyi Babatope       NaN  DIRECTOR
# 77800    1950416  tm1059008    Julian Gaviria       NaN  DIRECTOR
#
# [9772 rows x 5 columns]

# %% [markdown]
# 角色不影响最后分析高分电影的值。可以不用担心character的值影响最后结果

# %% [markdown]
# #### 清理重复数据

# %%
cleaned_titles.duplicated().sum()
# Out:
# 0

# %% [markdown]
# `cleaned_titles`中没有重复数据

# %%
cleaned_credits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# `cleaned_credits`中没有重复数据

# %% [markdown]
# #### 处理不一样数据

# %% [markdown]
# `cleaned_titles`中的`genres`和`original_credits`有可能出现不一致拼写。接下来进行查看

# %%
cleaned_titles["genres"].value_counts()
# Out:
# genres
# drama            3357
# comedy           2419
# thriller         1446
# action           1339
# romance          1080
# crime            1066
# documentation     981
# family            769
# animation         732
# fantasy           727
# european          679
# scifi             647
# horror            438
# history           336
# music             266
# reality           226
# war               221
# sport             188
# western            53
# Name: count, dtype: int64

# %% [markdown]
# 没有出现重复值

# %% [markdown]
# 接下里分析`production_countries`

# %%
cleaned_titles["production_countries"].value_counts()
# Out:
# production_countries
# US    5648
# IN    1610
# GB    1068
# JP    1046
# FR     720
#       ...
# GT       1
# CU       1
# LK       1
# NP       1
# FO       1
# Name: count, Length: 108, dtype: int64

# %% [markdown]
# 太多数值，无法看完。用`display.max_row()`设置为`none`来看查看全部的值

# %%
with pd.option_context('display.max_row()', None):
    print(cleaned_titles["production_countries"].value_counts())
# Out:
# production_countries
# US         5648
# IN         1610
# GB         1068
# JP         1046
# FR          720
# KR          637
# ES          637
# CA          608
# DE          383
# CN          295
# MX          264
# IT          224
# BR          221
# AU          217
# TR          195
# PH          192
# AR          150
# ID          149
# BE          148
# TW          133
# NG          131
# PL          126
# ZA          103
# NL          102
# HK          102
# CO           94
# EG           93
# DK           89
# TH           87
# SE           81
# LB           70
# NO           68
# AE           52
# IE           49
# SG           47
# XX           43
# IL           42
# RU           41
# CL           35
# CH           33
# PS           32
# BG           31
# MY           30
# SA           28
# AT           28
# IS           28
# LU           27
# NZ           27
# PE           26
# RO           25
# QA           24
# CZ           22
# JO           19
# FI           18
# ...

# %% [markdown]
# cleaned_titles["production_countries"]把`Lebanon`和`lb`进行一个合并。但是影响应该不会太大，因为`Lebanon`只有一个值

# %%
cleaned_titles["production_countries"] = cleaned_titles["production_countries"].replace({"LB" : "Lebanon"})

#检查是否还存在Lebanon
with pd.option_context('display.max_row()', None):
    print(cleaned_titles["production_countries"].value_counts())
# Out:
# production_countries
# US         5648
# IN         1610
# GB         1068
# JP         1046
# FR          720
# KR          637
# ES          637
# CA          608
# DE          383
# CN          295
# MX          264
# IT          224
# BR          221
# AU          217
# TR          195
# PH          192
# AR          150
# ID          149
# BE          148
# TW          133
# NG          131
# PL          126
# ZA          103
# HK          102
# NL          102
# CO           94
# EG           93
# DK           89
# TH           87
# SE           81
# Lebanon      71
# NO           68
# AE           52
# IE           49
# SG           47
# XX           43
# IL           42
# RU           41
# CL           35
# CH           33
# PS           32
# BG           31
# MY           30
# AT           28
# SA           28
# IS           28
# LU           27
# NZ           27
# PE           26
# RO           25
# QA           24
# CZ           22
# JO           19
# FI           18
# ...

# %% [markdown]
# 针对`original_credits`，不一致数据可能存在于`role`中，我们将查看是否存在多个不同值指代同一演职员类型的情况。

# %%
cleaned_credits["role"].value_counts()
# Out:
# role
# ACTOR       73251
# DIRECTOR     4550
# Name: count, dtype: int64

# %% [markdown]
# 只有两个值，为了节省空间，可以把这列的类型转换为Category，比字符串类型更节约内存空间，也能表明说值的类型有限。

# %%
cleaned_credits["role"] = cleaned_credits["role"].astype("category")
cleaned_credits["role"]
# Out:
# 0           ACTOR
# 1           ACTOR
# 2           ACTOR
# 3           ACTOR
# 4           ACTOR
#            ...
# 77796       ACTOR
# 77797       ACTOR
# 77798       ACTOR
# 77799       ACTOR
# 77800    DIRECTOR
# Name: role, Length: 77801, dtype: category
# Categories (2, object): ['ACTOR', 'DIRECTOR']

# %% [markdown]
# #### 处理无效或错误数据

# %% [markdown]
# 可以通过DataFrame的describe方法，对数值统计信息进行快速了解。

# %%
cleaned_titles.describe()
# Out:
#                         release_year       runtime      seasons    imdb_score  \
# count                          16970  16970.000000  5954.000000  16970.000000
# mean   2015-11-14 22:42:51.974072064     80.912552     2.455492      6.514207
# min              1954-01-01 00:00:00      0.000000     1.000000      1.500000
# 25%              2015-01-01 00:00:00     45.000000     1.000000      5.800000
# 50%              2018-01-01 00:00:00     90.000000     2.000000      6.600000
# 75%              2020-01-01 00:00:00    107.000000     3.000000      7.300000
# max              2022-01-01 00:00:00    225.000000    42.000000      9.500000
# std                              NaN     39.596172     2.869428      1.131095
#
#          imdb_votes  tmdb_popularity    tmdb_score
# count  1.694100e+04     16842.000000  16515.000000
# mean   3.281655e+04        29.396307      6.846933
# min    5.000000e+00         0.600000      1.000000
# 25%    7.800000e+02         4.070000      6.200000
# ...

# %%
cleaned_credits.describe()
# Out:
#           person_id
# count  7.780100e+04
# mean   5.294888e+05
# std    6.430167e+05
# min    7.000000e+00
# 25%    4.530600e+04
# 50%    1.983580e+05
# 75%    8.880960e+05
# max    2.462818e+06

# %% [markdown]
# 没有发现负数的值，这两个DataFrame都不需要清理

# %% [markdown]
# ### 整理数据

# %%
cleaned_credits
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %%
cleaned_titles
# Out:
#              id                               title   type  \
# 1       tm84618                         Taxi Driver  MOVIE
# 1       tm84618                         Taxi Driver  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# 2      tm154986                         Deliverance  MOVIE
# ...         ...                                 ...    ...
# 5846   tm898842                         C/O Kaadhal  MOVIE
# 5847  tm1059008                             Lokillo  MOVIE
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
# 5849   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description release_year  \
# 1     A mentally unstable Vietnam War veteran works ...   1976-01-01
# 1     A mentally unstable Vietnam War veteran works ...   1976-01-01
# ...

# %% [markdown]
# 为了能同时观察`cleaned_credits`和`cleaned_titles`中的值，需要讲两个DataFrame合并。他们都有`ID`这一列表。可以用这个列表来合并两个数据

# %%
credits_with_titles = pd.merge(cleaned_credits, cleaned_titles, on='id', how='inner')
credits_with_titles.head()
# Out:
#    person_id       id            name      character   role        title  \
# 0       3748  tm84618  Robert De Niro  Travis Bickle  ACTOR  Taxi Driver
# 1       3748  tm84618  Robert De Niro  Travis Bickle  ACTOR  Taxi Driver
# 2      14658  tm84618    Jodie Foster  Iris Steensma  ACTOR  Taxi Driver
# 3      14658  tm84618    Jodie Foster  Iris Steensma  ACTOR  Taxi Driver
# 4       7064  tm84618   Albert Brooks            Tom  ACTOR  Taxi Driver
#
#     type                                        description release_year  \
# 0  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 1  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 2  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 3  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
# 4  MOVIE  A mentally unstable Vietnam War veteran works ...   1976-01-01
#
#   age_certification  runtime genres production_countries  seasons    imdb_id  \
# ...

# %% [markdown]
# 对数据的整理，与分析方向紧密相关。此次数据分析目标是，**整理不同流派影视作品**，比如喜剧片、动作片、科幻片中，演员出演作品的平均IMDB评分，从而挖掘出各个流派中的**高评分作品演员**。

# %% [markdown]
# 电影名，不是很好下手的方向。可以从`role`先下手。先选出高分演员。

# %%
actor_with_titles = credits_with_titles.query('role=="ACTOR"')

# %% [markdown]
# 继续筛选，这次用`person_id` `genres`来筛选出演员与类型。不用`name`是因为名字可能出错，比如拼写错误等错误
#
# 有`groupby`这个方法来合并两个值

# %%
# groupby_genres_and_person_id = actor_with_titles.groupby(["genres", "person_id"])
groupby_genres_and_person_id = actor_with_titles.groupby(["genres", "person_id"])

# %% [markdown]
# 分组后，我们只需要对imdb_score的值进行聚合计算，因此只提取imdb_score变量，然后调用mean，来计算各个流派影视作品中，每位演员参演作品的平均IMDB评分。

# %%
# imdb_score_groupby_genres_and_person_id = groupby_genres_and_person_id["imdb_score"].mean()
imdb_score_groupby_genres_and_person_id = groupby_genres_and_person_id["imdb_score"].mean()
imdb_score_groupby_genres_and_person_id
# Out:
# genres   person_id
# action   45           5.0
#          48           5.4
#          51           6.4
#          53           6.8
#          54           5.3
#                      ...
# western  2353339      6.9
#          2370848      6.1
#          2398539      3.8
#          2406218      6.0
#          2408082      7.3
# Name: imdb_score, Length: 168881, dtype: float64

# %% [markdown]
# 调用`reset_index`，对层次化索引进行重置，得到更加规整的`DataFrame`。

# %%
imdb_score_groupby_genres_and_person_id_df = imdb_score_groupby_genres_and_person_id.reset_index()
imdb_score_groupby_genres_and_person_id_df
# Out:
#          genres  person_id  imdb_score
# 0        action         45         5.0
# 1        action         48         5.4
# 2        action         51         6.4
# 3        action         53         6.8
# 4        action         54         5.3
# ...         ...        ...         ...
# 168876  western    2353339         6.9
# 168877  western    2370848         6.1
# 168878  western    2398539         3.8
# 168879  western    2406218         6.0
# 168880  western    2408082         7.3
#
# [168881 rows x 3 columns]

# %% [markdown]
# 继续做一些数据整理，比如对上面的结果再次进行分组，找出各个流派里演员作品最高的平均评分是多少、最高评分对应的演员名字是什么。
#
# 要得到这一结果，我们需要再次用`genres`进行分组，然后提取出`imdb_score`变量，计算其最大值。

# %%
genres_max_scores = imdb_score_groupby_genres_and_person_id_df.groupby('genres')['imdb_score'].max()
genres_max_scores
# Out:
# genres
# action           9.3
# animation        9.3
# comedy           9.2
# crime            9.5
# documentation    9.1
# drama            9.5
# european         8.9
# family           9.3
# fantasy          9.3
# history          9.1
# horror           9.0
# music            8.8
# reality          8.9
# romance          9.2
# scifi            9.3
# sport            9.1
# thriller         9.5
# war              8.8
# western          8.9
# Name: imdb_score, dtype: float64

# %% [markdown]
# 知道最高分后，可以把以上结果和之前得到的`imdb_score_groupby_genres_and_person_id_df`再次进行连接，得到最高分对应的各个演员ID是什么，也就是这个最高平均分是哪位演员拿到的。

# %%
genres_max_score_with_person_id = pd.merge(genres_max_scores, imdb_score_groupby_genres_and_person_id_df, 
                                           on=["genres", "imdb_score" ])
genres_max_score_with_person_id
# Out:
#       genres  imdb_score  person_id
# 0     action         9.3       1303
# 1     action         9.3      12790
# 2     action         9.3      21033
# 3     action         9.3      86591
# 4     action         9.3     336830
# ..       ...         ...        ...
# 131      war         8.8     826547
# 132  western         8.9      22311
# 133  western         8.9      28166
# 134  western         8.9      28180
# 135  western         8.9      93017
#
# [136 rows x 3 columns]

# %% [markdown]
# 从以上结果可以看出，最高分对应的演员不一定只有一位，可能有多位演员的平均得分相同。
#
# 为了得到演员ID所对应的演员名字，和cleaned_credits这个DataFrame进行连接。这个DataFrame还有其它列，我们只需要得到person_id和name的对应，所以可以先提取出那两列，并把重复行删除。

# %%
actor_id_with_names = cleaned_credits[['person_id', 'name']].drop_duplicates()
actor_id_with_names.head(10)
# Out:
#    person_id             name
# 0       3748   Robert De Niro
# 1      14658     Jodie Foster
# 2       7064    Albert Brooks
# 3       3739    Harvey Keitel
# 4      48933  Cybill Shepherd
# 5      32267      Peter Boyle
# 6     519612   Leonard Harris
# 7      29068   Diahnne Abbott
# 8     519613      Gino Ardito
# 9       3308  Martin Scorsese

# %% [markdown]
# 合并`actor_id_with_names` 与 `genres_max_score_with_person_id `
